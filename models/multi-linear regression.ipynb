# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
spotify = pd.read_csv('decades.csv')
spotify.head()
# Out:
#    Unnamed: 0                                                url      WeekID  \
# 0           1  http://www.billboard.com/charts/hot-100/2014-0...   3/22/2014
# 1           2  http://www.billboard.com/charts/hot-100/2009-1...  10/10/2009
# 2           3  http://www.billboard.com/charts/hot-100/1998-1...  10/10/1998
# 3           6  http://www.billboard.com/charts/hot-100/2012-0...   4/14/2012
# 4           8  http://www.billboard.com/charts/hot-100/2007-1...   12/1/2007
#
#    Week Position               Song_x       Performer_x  \
# 0             45                 Sail        AWOLNATION
# 1             48            I'm Yours        Jason Mraz
# 2             45        How Do I Live       LeAnn Rimes
# 3             49  Rolling In The Deep             Adele
# 4             47     Before He Cheats  Carrie Underwood
#
#                              SongID  Instance  Previous Week Position  \
# 0                    SailAWOLNATION         2                    41.0
# 1               I'm YoursJason Mraz         1                    49.0
# 2          How Do I LiveLeAnn Rimes         1                    48.0
# 3          Rolling In The DeepAdele         2                    43.0
# 4  Before He CheatsCarrie Underwood         1                    43.0
#
#    Peak Position  ...  mode speechiness acousticness instrumentalness  \
# 0             17  ...   1.0      0.0568        0.452            0.609
# 1              6  ...   1.0      0.0468        0.595            0.000
# 2              2  ...   1.0      0.0279        0.128            0.000
# 3              1  ...   1.0      0.0294        0.131            0.000
# 4              8  ...   0.0      0.0405        0.271            0.000
#
#   liveness valence    tempo  time_signature  year  Decade
# 0   0.0953   0.243  119.038             4.0  2014   2010s
# 1   0.1050   0.718  150.953             4.0  2009   2000s
# 2   0.0822   0.258  128.303             4.0  1998   1990s
# 3   0.0527   0.522  104.945             4.0  2012   2010s
# 4   0.1190   0.290  147.905             4.0  2007   2000s
#
# [5 rows x 34 columns]

# %%
Decade_2010v1950s = spotify.loc[spotify['Decade'].isin(['2010s','1950s'])]

# %%
Decade_2010v1950s
# Out:
#        Unnamed: 0                                                url  \
# 0               1  http://www.billboard.com/charts/hot-100/2014-0...
# 3               6  http://www.billboard.com/charts/hot-100/2012-0...
# 5              10  http://www.billboard.com/charts/hot-100/2013-0...
# 6              15  http://www.billboard.com/charts/hot-100/2014-1...
# 7              16  http://www.billboard.com/charts/hot-100/2015-1...
# ...           ...                                                ...
# 10710       22139  http://www.billboard.com/charts/hot-100/1959-0...
# 10713       22148  https://www.billboard.com/charts/hot-100/2018-...
# 10714       22150  https://www.billboard.com/charts/hot-100/2018-...
# 10715       22151  http://www.billboard.com/charts/hot-100/2016-0...
# 10717       22154  https://www.billboard.com/charts/hot-100/2018-...
#
#            WeekID  Week Position                 Song_x  \
# 0       3/22/2014             45                   Sail
# 3       4/14/2012             49    Rolling In The Deep
# 5       8/24/2013             50                 Ho Hey
# 6       12/6/2014             43              All Of Me
# 7      11/28/2015             45      Thinking Out Loud
# ...           ...            ...                    ...
# 10710   3/28/1959             94       Wishful Thinking
# 10713   4/28/2018             68             Bickenhead
# 10714   8/25/2018             66  Stop Trying To Be God
# 10715   5/21/2016             66          Daddy Lessons
# 10717   8/25/2018             69              Can't Say
#
#                             Performer_x  \
# 0                            AWOLNATION
# 3                                 Adele
# 5                         The Lumineers
# 6                           John Legend
# 7                            Ed Sheeran
# ...                                 ...
# 10710  Little Anthony And The Imperials
# 10713                           Cardi B
# 10714                      Travis Scott
# 10715                           Beyonce
# 10717                      Travis Scott
#
#                                                  SongID  Instance  \
# 0                                        SailAWOLNATION         2
# 3                              Rolling In The DeepAdele         2
# 5                                   Ho HeyThe Lumineers         1
# 6                                  All Of MeJohn Legend         3
# 7                           Thinking Out LoudEd Sheeran         1
# ...                                                 ...       ...
# 10710  Wishful ThinkingLittle Anthony And The Imperials         1
# 10713                                 BickenheadCardi B         1
# 10714                 Stop Trying To Be GodTravis Scott         1
# 10715                              Daddy LessonsBeyonce         1
# 10717                             Can't SayTravis Scott         1
#
#        Previous Week Position  Peak Position  ...  mode speechiness  \
# 0                        41.0             17  ...   1.0      0.0568
# 3                        43.0              1  ...   1.0      0.0294
# 5                        44.0              3  ...   1.0      0.0304
# 6                        36.0              1  ...   1.0      0.0322
# 7                        41.0              2  ...   1.0      0.0295
# ...                       ...            ...  ...   ...         ...
# 10710                    79.0             79  ...   1.0      0.0266
# 10713                    43.0             43  ...   1.0      0.3030
# 10714                    27.0             27  ...   0.0      0.0628
# 10715                    41.0             41  ...   1.0      0.2160
# 10717                    38.0             38  ...   0.0      0.0547
#
#       acousticness instrumentalness liveness valence    tempo  time_signature  \
# 0            0.452         0.609000   0.0953   0.243  119.038             4.0
# 3            0.131         0.000000   0.0527   0.522  104.945             4.0
# 5            0.794         0.000002   0.0915   0.353   79.936             4.0
# 6            0.922         0.000000   0.1320   0.331  119.930             4.0
# 7            0.474         0.000000   0.1840   0.591   78.998             4.0
# ...            ...              ...      ...     ...      ...             ...
# 10710        0.805         0.000020   0.3510   0.655   97.088             3.0
# 10713        0.154         0.000002   0.1580   0.907  155.938             4.0
# 10714        0.221         0.000000   0.1350   0.113  150.009             4.0
# 10715        0.273         0.000000   0.3490   0.598   90.886             4.0
# 10717        0.201         0.000000   0.1180   0.713  147.980             4.0
#
#        year  Decade
# 0      2014   2010s
# 3      2012   2010s
# 5      2013   2010s
# 6      2014   2010s
# 7      2015   2010s
# ...     ...     ...
# 10710  1959   1950s
# 10713  2018   2010s
# 10714  2018   2010s
# 10715  2016   2010s
# 10717  2018   2010s
#
# [1650 rows x 34 columns]

# %%
Decade_2010v1950s.drop(["WeekID", "Week Position", "Song_x", "Performer_x", "Instance", "Previous Week Position", "Performer_y", "Song_y", "spotify_genre", "spotify_track_preview_url","spotify_track_album", "spotify_track_duration_ms" ], axis=1)
# Out:
#        Unnamed: 0                                                url  \
# 0               1  http://www.billboard.com/charts/hot-100/2014-0...
# 3               6  http://www.billboard.com/charts/hot-100/2012-0...
# 5              10  http://www.billboard.com/charts/hot-100/2013-0...
# 6              15  http://www.billboard.com/charts/hot-100/2014-1...
# 7              16  http://www.billboard.com/charts/hot-100/2015-1...
# ...           ...                                                ...
# 10710       22139  http://www.billboard.com/charts/hot-100/1959-0...
# 10713       22148  https://www.billboard.com/charts/hot-100/2018-...
# 10714       22150  https://www.billboard.com/charts/hot-100/2018-...
# 10715       22151  http://www.billboard.com/charts/hot-100/2016-0...
# 10717       22154  https://www.billboard.com/charts/hot-100/2018-...
#
#                                                  SongID  Peak Position  \
# 0                                        SailAWOLNATION             17
# 3                              Rolling In The DeepAdele              1
# 5                                   Ho HeyThe Lumineers              3
# 6                                  All Of MeJohn Legend              1
# 7                           Thinking Out LoudEd Sheeran              2
# ...                                                 ...            ...
# 10710  Wishful ThinkingLittle Anthony And The Imperials             79
# 10713                                 BickenheadCardi B             43
# 10714                 Stop Trying To Be GodTravis Scott             27
# 10715                              Daddy LessonsBeyonce             41
# 10717                             Can't SayTravis Scott             38
#
#        Weeks on Chart        spotify_track_id  spotify_track_explicit  \
# 0                  79  5xhQChGGhKLWqBqX4XhtYE                   False
# 3                  65  1CkvWZme3pRgbzaxZnTl5X                   False
# 5                  62  0W4Kpfp1w2xkY3PrV714B7                   False
# 6                  59  3U4isOIWM3VvDubwSI3y7a                   False
# 7                  58  34gCuhDGsG4bRPIf9bb02f                   False
# ...               ...                     ...                     ...
# 10710               2  4zPqq76FbCHMocdIj0F7OQ                   False
# 10713               2  17Yq72h0p15OhCbZ5lJ5gd                    True
# 10714               2  1xYpVRspgaLxdJLOTQkTjg                    True
# 10715               2  71OvX5NNLrmz7rpq1ANTQn                   False
# 10717               2  27a1mYSG5tYg7dmEjWBcmL                    True
#
#        spotify_track_popularity  danceability  energy  ...  mode  speechiness  \
# 0                          74.0         0.825   0.435  ...   1.0       0.0568
# 3                          76.0         0.729   0.756  ...   1.0       0.0294
# 5                          71.0         0.685   0.466  ...   1.0       0.0304
# 6                          87.0         0.422   0.264  ...   1.0       0.0322
# 7                          84.0         0.781   0.445  ...   1.0       0.0295
# ...                         ...           ...     ...  ...   ...          ...
# 10710                      11.0         0.581   0.570  ...   1.0       0.0266
# 10713                      64.0         0.884   0.814  ...   1.0       0.3030
# 10714                      74.0         0.588   0.567  ...   0.0       0.0628
# 10715                      71.0         0.643   0.503  ...   1.0       0.2160
# 10717                      80.0         0.702   0.708  ...   0.0       0.0547
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0             0.452          0.609000    0.0953    0.243  119.038
# 3             0.131          0.000000    0.0527    0.522  104.945
# 5             0.794          0.000002    0.0915    0.353   79.936
# 6             0.922          0.000000    0.1320    0.331  119.930
# 7             0.474          0.000000    0.1840    0.591   78.998
# ...             ...               ...       ...      ...      ...
# 10710         0.805          0.000020    0.3510    0.655   97.088
# 10713         0.154          0.000002    0.1580    0.907  155.938
# 10714         0.221          0.000000    0.1350    0.113  150.009
# 10715         0.273          0.000000    0.3490    0.598   90.886
# 10717         0.201          0.000000    0.1180    0.713  147.980
#
#        time_signature  year  Decade
# 0                 4.0  2014   2010s
# 3                 4.0  2012   2010s
# 5                 4.0  2013   2010s
# 6                 4.0  2014   2010s
# 7                 4.0  2015   2010s
# ...               ...   ...     ...
# 10710             3.0  1959   1950s
# 10713             4.0  2018   2010s
# 10714             4.0  2018   2010s
# 10715             4.0  2016   2010s
# 10717             4.0  2018   2010s
#
# [1650 rows x 22 columns]

# %%
# Assign X (data) and y (target)

### BEGIN SOLUTION
X = Decade_2010v1950s[['loudness', 'valence', 'speechiness', 'acousticness']]
y = Decade_2010v1950s['spotify_track_popularity'].values.reshape(-1, 1)
print(X.shape, y.shape)
### END SOLUTION
# Out:
# (1650, 4) (1650, 1)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.5823968812370521, R2: 0.3769151659593386

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.5821639881760132, R2: 0.3771643296121014

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.5823966239677622, R2: 0.37691544120221515

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.5820753702259573, R2: 0.3772591386718379

# %%
from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()

### END SOLUTION

# %%
# Fit the model to the data. 
# Note: This is the training step where you fit the line to the data.

### BEGIN SOLUTION

model.fit(X, y)

### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Print the coefficient and the intercept for the model

### BEGIN SOLUTION
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
### END SOLUTION
# Out:
# Weight coefficients:  [[1.]]
# y-axis intercept:  [1.42108547e-14]

# %%
# Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([X.min()])
x_max = np.array([X.max()])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[0.]]
# Max X Value: [[100.]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max

### BEGIN SOLUTION
y_min = model.predict(x_min)
y_max = model.predict(x_max)
### END SOLUTION

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

### BEGIN SOLUTION
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
### END SOLUTION

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to predict a value
predicted = model.predict(X)

# Score the prediction with mse and r2
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 2.2079798401807593e-29
# R-squared (R2 ): 1.0

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: [74.]
# Predicted output: [74.]
# Prediction Error: [0.]

# %%
model.score(X,y)
# Out:
# 1.0
